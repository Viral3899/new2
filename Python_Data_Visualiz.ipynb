# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
import numpy as np
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
x = [5, 2, 9, 4, 7] 
  
y = [10, 5, 8, 4, 2] 
  
plt.plot(x,y) 
  
plt.show()

# %% [markdown]
# # Formatting style

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'o') # try ro
plt.axis([0, 6, 0, 20])
plt.show()

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# # marker style

# %%
ypoints = np.array([2,4,3,6,5,8,7])

plt.plot(ypoints, marker = '*')  #try 0, + , |
plt.show()

# %%
#marker size

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
#marker border
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
#changing line style

plt.plot(ypoints, 'o:r') #try - , : , 
plt.show()

# %%
#line style
plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
plt.plot(ypoints, linestyle = 'dashed')

# %%
#color
plt.plot(ypoints, color = 'r')  #hotpink
plt.show()

# %%
#width
plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %% [markdown]
# # subplot

# %%
x = np.array([2,4,3,6,4,8,7])
y = np.array([1,2,3,4,5,6,7])

plt.subplot(1, 2, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([2,4,6,8])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([2,4,3,6,4,8,7])
y = np.array([1,2,3,4,5,6,7])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([2,4,6,8])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([2,3,4,5])

plt.subplot(2, 2, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([2,5,3,7])

plt.subplot(2, 2, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 2, 3)
plt.plot(x,y)

x = np.array([11,12,10,13])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 4)
plt.plot(x,y)



#plt.show()

# %%
#Tiles
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("Title 1")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("Title 2")

plt.show()

# %%
#Main title
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([2,5,3,8])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("Title 1")

#plot 2:
x = np.array([0, 2,5,3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("Tile 2")

plt.suptitle("Main Title")
plt.show()

# %% [markdown]
# # Scatter plot

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11])
y = np.array([34,54,64,74,83,65,92,25,75,89])

plt.scatter(x, y)
plt.show()

# %%
#comparing 2 scatter plot
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# # Bar plot

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([2,4,6,8])

plt.bar(x,y)
plt.show()

# %%
x = ["USA", "INDIA"]
y = [121, 99]
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([8,6,4,2])

plt.barh(x, y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D","E"])
y = np.array([2,4,3,6,5])

plt.bar(x, y, color = "red")
plt.show()

# %%
x = np.array(["A", "B", "C", "D","E"])
y = np.array([2,4,3,6,5])

plt.bar(x, y, color = "hotpink")
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([2,4,6,8])

plt.bar(x, y, width = 0.3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([2,3,4,5])

plt.barh(x, y, height = 0.5)
plt.show()

# %% [markdown]
# # Histogram

# %% [markdown]
# ### A histogram is a plot that lets you discover, and show, the underlying frequency distribution (shape) of a set of continuous data. This allows the inspection of the data for its underlying distribution (e.g., normal distribution), outliers, skewness, etc.

# %%
x = np.random.normal(150,10, 250)
print(x)
plt.hist(x)
plt.show()
# Out:
# [151.34090887 145.65337784 134.31097755 155.32991974 160.05624656
#  161.76824547 160.62994846 152.69934618 155.42117098 145.46776414
#  159.79767438 144.75148052 144.6202791  150.6532328  158.43124606
#  149.5103736  131.2991675  144.09684042 158.34831912 147.37064519
#  136.56201405 145.81252736 148.41459889 161.30183037 158.93263485
#  160.23642506 158.13323966 158.13697868 138.92636486 146.03822146
#  152.14595169 148.51697936 151.75488175 139.32574963 150.78632301
#  164.23788565 138.98894248 163.14056614 138.20250782 158.14262314
#  162.80496819 160.28802819 137.78504656 144.82183952 184.0077275
#  158.23128078 148.80641805 145.48098285 153.51728166 144.80698881
#  148.9227271  159.85651635 146.53136366 149.70937413 150.61757407
#  157.64572875 160.20620056 153.39652656 143.02023075 148.24917217
#  147.28863297 150.51647642 136.19324199 149.12710475 150.56588126
#  152.32829508 147.62210035 161.4798323  147.21893951 150.65821901
#  145.27619995 163.40585522 158.19797148 138.38856072 148.35667032
#  153.82214397 159.72511696 148.44782623 156.19997685 132.04816897
#  159.76779431 164.38582805 144.19697715 155.43443595 176.5918698
#  158.51549117 144.56181047 142.39193247 141.46382318 153.2431443
#  157.70151912 157.80071222 150.93249123 154.72573349 143.23773404
#  145.0176583  150.33781202 148.85606341 143.44939206 163.67606011
#  152.41262918 149.9920955  157.11203707 148.49558696 148.42885564
#  147.29261123 140.36650457 147.78157329 168.45961983 136.36265793
#  148.67178845 164.91210685 142.4348496  145.00409953 140.39250709
#  151.67218077 151.86033709 147.1879924  145.03752875 145.46673361
#  153.24435448 151.70184182 157.47774501 140.40078264 150.07329095
#  156.90076498 159.63682004 146.10983385 153.34931678 138.21224794
#  174.29670632 147.0600008  150.42799188 162.18352804 158.14733424
#  159.48135425 151.66455575 151.41264205 145.94213241 153.11598032
#  151.19621956 156.430216   168.4768052  155.39418832 134.74959229
#  149.61417505 156.17894956 145.0633475  147.38727407 132.40967992
#  159.47664124 153.63838651 146.69397202 153.31375715 148.76172098
#  164.30743762 157.83614538 177.26879478 146.94541659 135.72139758
#  165.14681475 151.42614018 153.50427014 156.13565406 146.70882196
#  145.75928979 140.59300129 124.96678066 154.68722524 170.87917018
#  149.054654   144.34475339 167.16962329 169.31485527 161.44405893
#  131.18850661 166.35418329 169.02994393 165.80480796 153.72530197
#  139.42333701 150.50677257 159.38966717 158.83238555 158.76385533
#  129.41906621 131.31501095 151.91401359 153.40459253 145.89395593
#  153.54165528 161.57765525 144.51772512 145.27985665 152.78729412
#  158.43112751 145.94319192 140.24365921 152.66355372 151.05533469
#  138.04654977 163.68643956 145.68182771 143.68962513 155.79386709
#  152.95538084 167.37774329 140.26218791 162.94358504 158.60870162
#  147.71286091 161.9724558  148.25250082 162.78767488 155.13875721
#  171.98198724 138.87301427 156.24907351 156.45173399 155.27918731
#  134.38831728 157.43806234 152.54725155 148.39600255 164.24175996
#  154.39841316 159.14153354 155.07816279 150.43459529 165.63724443
#  150.32965199 159.89121108 160.01343545 164.40917    150.03556138
#  145.67236744 136.13435466 149.40021799 161.11348195 155.11137162
#  159.38524274 153.01376149 148.79208475 157.11308428 136.18834963
#  152.19419428 152.64020211 151.16732957 139.14350423 159.53503348]

# %% [markdown]
# # Pia chart

# %%
y = np.array([20,35,10,45])

plt.pie(y)
plt.show()

# %%
#labels
y = np.array([20,35,10,45])
mylabels = ["USA", "India", "Russia", "China"]

plt.pie(y, labels=mylabels,autopct='%1.1f%%')  # autopct for show percentage
plt.show()

# %%
#angle set
plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
#explode
myexplode = [0, 0.1, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
#shoadow
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
#color
mycolors = ["black", "red", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
#legend
plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
#legend with title
plt.pie(y, labels = mylabels)
plt.legend(title = "Country")
plt.show()

# %% [markdown]
# # Boxplot

# %% [markdown]
# #### Boxplots are a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”).

# %%
np.random.seed(10) 
  
data_1 = np.random.normal(100, 10, 200) 
data_2 = np.random.normal(90, 20, 200) 
data_3 = np.random.normal(80, 30, 200) 
data_4 = np.random.normal(70, 40, 200) 
data = [data_1, data_2, data_3, data_4] 
  
fig = plt.figure(figsize =(10, 7)) 
  
# Creating axes instance 
ax = fig.add_axes([0, 0, 1, 1]) 
  
# Creating plot 
bp = ax.boxplot(data) 
  
# show plot 
plt.show()
