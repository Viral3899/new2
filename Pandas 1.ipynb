# %%
import pandas as pd
df=pd.read_excel("pandas 100 sales.xlsx")
df.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27     159.42     2533654.00
# 1        Online              C 2012-09-15     117.11      576782.80
# 2       Offline              L 2014-08-05     524.96     1158502.59
# 3        Online              C 2014-05-07       6.92       75591.66
# 4       Offline              L 2013-06-02     524.96     3296425.02
#
#    Total_Profit
# 0     951410.50
# 1     248406.36
# 2     224598.75
# 3      19525.82
# ...

# %%
print(df.query('Item_Type=="Fruits" & Sales_Channel=="Offline"'))
df[df['Country']=='Tuvalu']
# Out:
#                 Region                Country Item_Type Sales_Channel  \
# 54  Sub_Saharan Africa  Sao Tome and Principe    Fruits       Offline
# 96                Asia               Malaysia    Fruits       Offline
#
#    Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 54              H 2013-10-24       6.92       71253.21      18405.17
# 96              L 2011-12-28       6.92       58471.11      15103.47
#                   Region Country  Item_Type Sales_Channel Order_Priority  \
# 0  Australia and Oceania  Tuvalu  Baby Food       Offline              H
#
#    Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 0 2010-06-27     159.42      2533654.0      951410.5

# %%
df['Item_Type'].value_counts()
# Out:
# Clothes            13
# Cosmetics          13
# Office Supplies    12
# Fruits             10
# Personal Care      10
# Household           9
# Beverages           8
# Baby Food           7
# Cereal              7
# Vegetables          6
# Snacks              3
# Meat                2
# Name: Item_Type, dtype: int64

# %%
import numpy as np

# %%
df[df['Country'].isin(['Grenada','Rwanda'])]
# Out:
#                                Region  Country        Item_Type Sales_Channel  \
# 1   Central America and the Caribbean  Grenada           Cereal        Online
# 4                  Sub_Saharan Africa   Rwanda  Office Supplies       Offline
# 65                 Sub_Saharan Africa   Rwanda        Cosmetics       Offline
#
#    Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 1               C 2012-09-15     117.11      576782.80     248406.36
# 4               L 2013-06-02     524.96     3296425.02     639077.50
# 65              H 2013-11-25     263.33     1957344.40     778415.99

# %%
(df['Country']=='Grenada')|(df['Country']=='Rwanda')
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4      True
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: Country, Length: 100, dtype: bool

# %%
(df['Country'].isin(['Grenada','Rwanda']))
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4      True
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: Country, Length: 100, dtype: bool

# %%
# if df['Country']=='Grenada' or df['Country']=='Rwanda':
#     df['extra']=0
# else:
#     df['extra']=1

df['extra']=np.where((df['Country'].isin(['Grenada','Rwanda'])),1,0)

# %%
pd.date_range("2017-01-15", "2017-01-20")
# Out:
# DatetimeIndex(['2017-01-15', '2017-01-16', '2017-01-17', '2017-01-18',
#                '2017-01-19', '2017-01-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np   
import pandas as pd

# Make a DataFrame with dates and random numbers
df = pd.DataFrame(np.random.random((30, 3)))
df['date'] = pd.date_range('2017-1-1', periods=30, freq='D')

# Select the rows between two dates
in_range_df = df[df["date"].isin(pd.date_range("2017-01-15", "2017-01-20"))]

print(in_range_df)
# Out:
#            0         1         2       date
# 14  0.204166  0.449824  0.573761 2017-01-15
# 15  0.240580  0.517867  0.285026 2017-01-16
# 16  0.752238  0.938832  0.217813 2017-01-17
# 17  0.521209  0.335621  0.229609 2017-01-18
# 18  0.398825  0.873702  0.438761 2017-01-19
# 19  0.893842  0.676155  0.682078 2017-01-20

# %%
df
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %%
from datetime import datetime,date

# %%
max(df['Ship_Date'])
# Out:
# Timestamp('2017-06-17 00:00:00')

# %%
Start_day=int(input("Enter Start "))
Start_month=int(input("Enter Start "))
Start_year=int(input("Enter Start "))
End_day=int(input("Enter Start "))
End_month=int(input("Enter Start "))
End_year=int(input("Enter Start "))
start_date=date(Start_year,Start_month,Start_day)
start_date
# Out:
# Enter Start 1
# Enter Start 1
# Enter Start 2222
# Enter Start 22
# Enter Start 11
# Enter Start 2222
# datetime.date(2222, 1, 1)

# %%
def Count_CINPN():
    Start_day,Start_month,Start_year=(input("Enter Start day/month/year Comma Seperated: ").split(','))
    End_day,End_month,End_year=(input("Enter Start day/month/year Comma Seperated: ").split(','))
    
#     start_date=date(int(Start_year),int(Start_month),int(Start_day))
#     end_date=date(int(End_year),int(End_month),int(End_day))
#     start_date=pd.to_datetime(start_date)
#     end_date=pd.to_datetime(end_date)
    Currentyear=df[(df['Ship_Date']>=datetime(int(Start_year),int(Start_month),int(Start_day))) & (df['Ship_Date']<=datetime(int(End_year),int(End_month),int(End_day)))]
    print(Currentyear.shape)

# %%
df[df['Ship_Date']>=datetime(2015,12,31)]
# Out:
#                                Region       Country        Item_Type  \
# 12                               Asia    Bangladesh          Clothes
# 13  Central America and the Caribbean      Honduras        Household
# 16                               Asia     Sri Lanka        Cosmetics
# 22  Central America and the Caribbean      Honduras           Snacks
# 24                             Europe      Moldova     Personal Care
# 25                             Europe        France        Cosmetics
# 34                 Sub_Saharan Africa      Djibouti           Snacks
# 35  Central America and the Caribbean    Costa Rica    Personal Care
# 37                 Sub_Saharan Africa    The Gambia             Meat
# 40                 Sub_Saharan Africa         Niger    Personal Care
# 45                 Sub_Saharan Africa       Comoros           Cereal
# 46                             Europe       Iceland        Cosmetics
# 67  Central America and the Caribbean        Belize          Clothes
# ...

# %%
Count_CINPN()
# Out:
# Enter Start day/month/year Comma Seperated: 12,5,2015
# Enter Start day/month/year Comma Seperated: 12,5,2016
# (7, 10)

# %%
df[(df['Country']=='Grenada')|(df['Country']=='Rwanda')]
# Out:
#                                Region  Country        Item_Type Sales_Channel  \
# 1   Central America and the Caribbean  Grenada           Cereal        Online
# 4                  Sub_Saharan Africa   Rwanda  Office Supplies       Offline
# 65                 Sub_Saharan Africa   Rwanda        Cosmetics       Offline
#
#    Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  extra
# 1               C 2012-09-15     117.11      576782.80     248406.36      1
# 4               L 2013-06-02     524.96     3296425.02     639077.50      1
# 65              H 2013-11-25     263.33     1957344.40     778415.99      1

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item_Type', 'Sales_Channel', 'Order_Priority',
#        'Ship_Date', 'Unit_Cost', 'Total_Revenue', 'Total_Profit'],
#       dtype='object')

# %%
df.columns[0:3]
# Out:
# Index(['Region', 'Country', 'Item_Type'], dtype='object')

# %%
df.tail()
# Out:
#                 Region       Country      Item_Type Sales_Channel  \
# 95  Sub_Saharan Africa          Mali        Clothes        Online
# 96                Asia      Malaysia         Fruits       Offline
# 97  Sub_Saharan Africa  Sierra Leone     Vegetables       Offline
# 98       North America        Mexico  Personal Care       Offline
# 99  Sub_Saharan Africa    Mozambique      Household       Offline
#
#    Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 95              M 2011-03-09      35.84       97040.64      65214.72
# 96              L 2011-12-28       6.92       58471.11      15103.47
# 97              C 2016-06-29      90.93      228779.10      93748.05
# 98              M 2015-08-08      56.67      471336.91     144521.02
# 99              L 2012-02-15     502.54     3586605.09     889472.91

# %%
print(df["Region"].head())
# Out:
# 0                Australia and Oceania
# 1    Central America and the Caribbean
# 2                               Europe
# 3                   Sub_Saharan Africa
# 4                   Sub_Saharan Africa
# Name: Region, dtype: object

# %%
df.Region.head()
# Out:
# 0                Australia and Oceania
# 1    Central America and the Caribbean
# 2                               Europe
# 3                   Sub_Saharan Africa
# 4                   Sub_Saharan Africa
# Name: Region, dtype: object

# %%
df[["Region","Total_Profit"]].head()
# Out:
#                               Region  Total_Profit
# 0              Australia and Oceania     951410.50
# 1  Central America and the Caribbean     248406.36
# 2                             Europe     224598.75
# 3                 Sub_Saharan Africa      19525.82
# 4                 Sub_Saharan Africa     639077.50

# %%
df[["Total_Profit","Region"]].head()
# Out:
#    Total_Profit                             Region
# 0     951410.50              Australia and Oceania
# 1     248406.36  Central America and the Caribbean
# 2     224598.75                             Europe
# 3      19525.82                 Sub_Saharan Africa
# 4     639077.50                 Sub_Saharan Africa

# %%
Region_data=df["Region"]
Region_data
# Out:
# 0                 Australia and Oceania
# 1     Central America and the Caribbean
# 2                                Europe
# 3                    Sub_Saharan Africa
# 4                    Sub_Saharan Africa
#                     ...
# 95                   Sub_Saharan Africa
# 96                                 Asia
# 97                   Sub_Saharan Africa
# 98                        North America
# 99                   Sub_Saharan Africa
# Name: Region, Length: 100, dtype: object

# %%
df["Region&Country"]=df["Region"]+df["Country"]
df
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %%
df.head(1)
# Out:
#                   Region Country  Item_Type Sales_Channel Order_Priority  \
# 0  Australia and Oceania  Tuvalu  Baby Food       Offline              H
#
#    Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 0 2010-06-27     159.42      2533654.0      951410.5

# %%
df["Total_Profit_New"]=df["Total_Profit"]-1000
df
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %%
df["Region"][0:5]
# Out:
# 0                Australia and Oceania
# 1    Central America and the Caribbean
# 2                               Europe
# 3                   Sub_Saharan Africa
# 4                   Sub_Saharan Africa
# Name: Region, dtype: object

# %%
df["Region"][2:6]
# Out:
# 2                   Europe
# 3       Sub_Saharan Africa
# 4       Sub_Saharan Africa
# 5    Australia and Oceania
# Name: Region, dtype: object

# %%
df
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %%
df.loc[3:34:5,"Region":"Sales_Channel"]
# Out:
#                                Region                Country      Item_Type  \
# 3                  Sub_Saharan Africa  Sao Tome and Principe         Fruits
# 8                  Sub_Saharan Africa  Republic of the Congo  Personal Care
# 13  Central America and the Caribbean               Honduras      Household
# 18                               Asia           Turkmenistan      Household
# 23              Australia and Oceania            New Zealand         Fruits
# 28                             Europe                 Norway      Beverages
# 33                               Asia                Myanmar      Household
#
#    Sales_Channel
# 3         Online
# 8        Offline
# 13       Offline
# 18       Offline
# 23        Online
# 28       Offline
# 33       Offline

# %%
df.loc[[3,34],["Region","Total_Profit"]]
# Out:
#                 Region  Total_Profit
# 3   Sub_Saharan Africa      19525.82
# 34  Sub_Saharan Africa     404010.78

# %%
df.iloc[2,6]
# Out:
# 524.96

# %%
df.iloc[2:10,3:8]
# Out:
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue
# 2       Offline              L 2014-08-05     524.96     1158502.59
# 3        Online              C 2014-05-07       6.92       75591.66
# 4       Offline              L 2013-06-02     524.96     3296425.02
# 5        Online              C 2015-02-21     159.42      759202.72
# 6       Offline              M 2011-04-27     502.54     2798046.49
# 7        Online              H 2012-07-27      90.93     1245112.92
# 8       Offline              M 2015-08-25      56.67      496101.10
# 9        Online              H 2014-05-30     117.11     1356180.10

# %%
df.iloc[[2,5,10],[1,4,7]]
# Out:
#             Country Order_Priority  Total_Revenue
# 2            Russia              L     1158502.59
# 5   Solomon Islands              C      759202.72
# 10       Kyrgyzstan              H       19103.44

# %% [markdown]
#                                                     Filter

# %%
df[df["Sales_Channel"]=="Offline"]
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 2                              Europe                 Russia  Office Supplies
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# 6                  Sub_Saharan Africa                 Angola        Household
# 8                  Sub_Saharan Africa  Republic of the Congo    Personal Care
# 11                 Sub_Saharan Africa             Cape Verde          Clothes
# 13  Central America and the Caribbean               Honduras        Household
# 14                               Asia               Mongolia    Personal Care
# 16                               Asia              Sri Lanka        Cosmetics
# 17                 Sub_Saharan Africa               Cameroon        Beverages
# 18                               Asia           Turkmenistan        Household
# ...

# %%
df[df["Sales_Channel"]!="Offline"]
# Out:
#                                Region                           Country  \
# 1   Central America and the Caribbean                           Grenada
# 3                  Sub_Saharan Africa             Sao Tome and Principe
# 5               Australia and Oceania                   Solomon Islands
# 7                  Sub_Saharan Africa                      Burkina Faso
# 9                  Sub_Saharan Africa                           Senegal
# 10                               Asia                        Kyrgyzstan
# 12                               Asia                        Bangladesh
# 15                             Europe                          Bulgaria
# 19              Australia and Oceania                        East Timor
# 20                             Europe                            Norway
# 21                             Europe                          Portugal
# 22  Central America and the Caribbean                          Honduras
# ...

# %%
df[(df["Total_Profit"]>=150000) & (df["Total_Revenue"]>=50000)].value_counts(df["Order_Priority"]=="L")
# Out:
# Order_Priority
# False    46
# True     19
# dtype: int64

# %%
df[(df["Total_Profit"]>=150000) & (df["Total_Revenue"]>=50000)].count()
# Out:
# Region            65
# Country           65
# Item_Type         65
# Sales_Channel     65
# Order_Priority    65
# Ship_Date         65
# Unit_Cost         65
# Total_Revenue     65
# Total_Profit      65
# dtype: int64

# %%
df[(df["Item_Type"]=="Baby Food") & (df["Total_Revenue"]>=200000)].count() # Multiple condition Must be in Round Bracket
# Out:
# Region            7
# Country           7
# Item_Type         7
# Sales_Channel     7
# Order_Priority    7
# Ship_Date         7
# Unit_Cost         7
# Total_Revenue     7
# Total_Profit      7
# dtype: int64

# %%
df.mean()
# Out:
# <ipython-input-24-c61f0c8f89b5>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.mean()
# Unit_Cost        1.910480e+02
# Total_Revenue    1.373488e+06
# Total_Profit     4.416820e+05
# dtype: float64

# %%
df["Total_Profit"].mean()
# Out:
# 441681.98399999994

# %%
df["Unit_Cost"].mean()
# Out:
# 191.04800000000006

# %%
df.max()
# Out:
# Region             Sub_Saharan Africa
# Country                        Zambia
# Item_Type                  Vegetables
# Sales_Channel                  Online
# Order_Priority                      M
# Ship_Date         2017-06-17 00:00:00
# Unit_Cost                      524.96
# Total_Revenue              5997054.98
# Total_Profit               1719922.04
# dtype: object

# %%
df.min()
# Out:
# Region                           Asia
# Country                       Albania
# Item_Type                   Baby Food
# Sales_Channel                 Offline
# Order_Priority                      C
# Ship_Date         2010-01-08 00:00:00
# Unit_Cost                        6.92
# Total_Revenue                 4870.26
# Total_Profit                  1258.02
# dtype: object

# %%
df.median()
# Out:
# <ipython-input-29-6d467abf240d>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.median()
# Unit_Cost           107.275
# Total_Revenue    752314.360
# Total_Profit     290767.995
# dtype: float64

# %%
df["Unit_Cost"].median()
# Out:
# 107.275

# %%
df.std()
# Out:
# Ship_Date        754 days 19:07:17.646447584
# Unit_Cost                         188.208181
# Total_Revenue                 1460028.706824
# Total_Profit                    438537.90706
# dtype: object

# %%
df.var()
# Out:
# Unit_Cost        3.542232e+04
# Total_Revenue    2.131684e+12
# Total_Profit     1.923155e+11
# dtype: float64

# %%
df.describe()
# Out:
#         Unit_Cost  Total_Revenue  Total_Profit
# count  100.000000   1.000000e+02  1.000000e+02
# mean   191.048000   1.373488e+06  4.416820e+05
# std    188.208181   1.460029e+06  4.385379e+05
# min      6.920000   4.870260e+03  1.258020e+03
# 25%     35.840000   2.687212e+05  1.214436e+05
# 50%    107.275000   7.523144e+05  2.907680e+05
# 75%    263.330000   2.212045e+06  6.358288e+05
# max    524.960000   5.997055e+06  1.719922e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item_Type       100 non-null    object
#  3   Sales_Channel   100 non-null    object
#  4   Order_Priority  100 non-null    object
#  5   Ship_Date       100 non-null    datetime64[ns]
#  6   Unit_Cost       100 non-null    float64
#  7   Total_Revenue   100 non-null    float64
#  8   Total_Profit    100 non-null    float64
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 5.1+ KB

# %%
df["Region"].dtypes
# Out:
# dtype('O')

# %%
df[["Total_Profit","Region"]].dtypes
# Out:
# Total_Profit    float64
# Region           object
# dtype: object

# %%
df.skew()
# Out:
# Unit_Cost        0.858072
# Total_Revenue    1.277698
# Total_Profit     1.238555
# dtype: float64

# %%
df.kurt()
# Out:
# Unit_Cost       -0.830099
# Total_Revenue    0.804539
# Total_Profit     0.767398
# dtype: float64

# %%
df.kurtosis()
# Out:
# Unit_Cost       -0.830099
# Total_Revenue    0.804539
# Total_Profit     0.767398
# dtype: float64

# %%
df.corr()
# Out:
#                Unit_Cost  Total_Revenue  Total_Profit
# Unit_Cost       1.000000       0.715623      0.467214
# Total_Revenue   0.715623       1.000000      0.897327
# Total_Profit    0.467214       0.897327      1.000000

# %%
df[["Unit_Cost","Total_Profit"]].cov()
# Out:
#                  Unit_Cost  Total_Profit
# Unit_Cost     3.542232e+04  3.856216e+07
# Total_Profit  3.856216e+07  1.923155e+11

# %%
df.cov()
# Out:
#                   Unit_Cost  Total_Revenue  Total_Profit
# Unit_Cost      3.542232e+04   1.966455e+08  3.856216e+07
# Total_Revenue  1.966455e+08   2.131684e+12  5.745386e+11
# Total_Profit   3.856216e+07   5.745386e+11  1.923155e+11

# %%
df.apply(max)
# Out:
# Region             Sub_Saharan Africa
# Country                        Zambia
# Item_Type                  Vegetables
# Sales_Channel                  Online
# Order_Priority                      M
# Ship_Date         2017-06-17 00:00:00
# Unit_Cost                      524.96
# Total_Revenue              5997054.98
# Total_Profit               1719922.04
# dtype: object

# %%
new_df=df.drop(["Region"],axis=1)
new_df
# Out:
#                   Country        Item_Type Sales_Channel Order_Priority  \
# 0                  Tuvalu        Baby Food       Offline              H
# 1                 Grenada           Cereal        Online              C
# 2                  Russia  Office Supplies       Offline              L
# 3   Sao Tome and Principe           Fruits        Online              C
# 4                  Rwanda  Office Supplies       Offline              L
# ..                    ...              ...           ...            ...
# 95                   Mali          Clothes        Online              M
# 96               Malaysia           Fruits       Offline              L
# 97           Sierra Leone       Vegetables       Offline              C
# 98                 Mexico    Personal Care       Offline              M
# 99             Mozambique        Household       Offline              L
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# ...

# %%
# df.drop(["Region"],axis=1,inplace=True)  



# Change in Original Data

# %%
df.drop(["Region","Total_Profit"],axis=1).head()
# Out:
#                  Country        Item_Type Sales_Channel Order_Priority  \
# 0                 Tuvalu        Baby Food       Offline              H
# 1                Grenada           Cereal        Online              C
# 2                 Russia  Office Supplies       Offline              L
# 3  Sao Tome and Principe           Fruits        Online              C
# 4                 Rwanda  Office Supplies       Offline              L
#
#    Ship_Date  Unit_Cost  Total_Revenue
# 0 2010-06-27     159.42     2533654.00
# 1 2012-09-15     117.11      576782.80
# 2 2014-08-05     524.96     1158502.59
# 3 2014-05-07       6.92       75591.66
# 4 2013-06-02     524.96     3296425.02

# %%
df.drop(df.columns[0:3],axis=1).head()
# Out:
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27     159.42     2533654.00
# 1        Online              C 2012-09-15     117.11      576782.80
# 2       Offline              L 2014-08-05     524.96     1158502.59
# 3        Online              C 2014-05-07       6.92       75591.66
# 4       Offline              L 2013-06-02     524.96     3296425.02
#
#    Total_Profit
# 0     951410.50
# 1     248406.36
# 2     224598.75
# 3      19525.82
# 4     639077.50

# %%
df.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27     159.42     2533654.00
# 1        Online              C 2012-09-15     117.11      576782.80
# 2       Offline              L 2014-08-05     524.96     1158502.59
# 3        Online              C 2014-05-07       6.92       75591.66
# 4       Offline              L 2013-06-02     524.96     3296425.02
#
#    Total_Profit
# 0     951410.50
# 1     248406.36
# 2     224598.75
# 3      19525.82
# ...

# %%
df.drop(df.columns[[0,3]],axis=1).head()
# Out:
#                  Country        Item_Type Order_Priority  Ship_Date  \
# 0                 Tuvalu        Baby Food              H 2010-06-27
# 1                Grenada           Cereal              C 2012-09-15
# 2                 Russia  Office Supplies              L 2014-08-05
# 3  Sao Tome and Principe           Fruits              C 2014-05-07
# 4                 Rwanda  Office Supplies              L 2013-06-02
#
#    Unit_Cost  Total_Revenue  Total_Profit
# 0     159.42     2533654.00     951410.50
# 1     117.11      576782.80     248406.36
# 2     524.96     1158502.59     224598.75
# 3       6.92       75591.66      19525.82
# 4     524.96     3296425.02     639077.50

# %%
df.drop(df.columns[3],axis=1).head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 0              H 2010-06-27     159.42     2533654.00     951410.50
# 1              C 2012-09-15     117.11      576782.80     248406.36
# 2              L 2014-08-05     524.96     1158502.59     224598.75
# 3              C 2014-05-07       6.92       75591.66      19525.82
# 4              L 2013-06-02     524.96     3296425.02     639077.50

# %%
df.drop([1,6])
# Out:
#                    Region                Country        Item_Type  \
# 0   Australia and Oceania                 Tuvalu        Baby Food
# 2                  Europe                 Russia  Office Supplies
# 3      Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4      Sub_Saharan Africa                 Rwanda  Office Supplies
# 5   Australia and Oceania        Solomon Islands        Baby Food
# ..                    ...                    ...              ...
# 95     Sub_Saharan Africa                   Mali          Clothes
# 96                   Asia               Malaysia           Fruits
# 97     Sub_Saharan Africa           Sierra Leone       Vegetables
# 98          North America                 Mexico    Personal Care
# 99     Sub_Saharan Africa             Mozambique        Household
#
#    Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0        Offline              H 2010-06-27     159.42     2533654.00
# ...

# %%
df.drop(df.loc[:, 'Country':'Total_Profit'].columns, axis = 1).head()
# Out:
#                               Region
# 0              Australia and Oceania
# 1  Central America and the Caribbean
# 2                             Europe
# 3                 Sub_Saharan Africa
# 4                 Sub_Saharan Africa

# %%
df.drop(df.loc[:,"Region":"Sales_Channel"].columns,axis=1)
# Out:
#    Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 0               H 2010-06-27     159.42     2533654.00     951410.50
# 1               C 2012-09-15     117.11      576782.80     248406.36
# 2               L 2014-08-05     524.96     1158502.59     224598.75
# 3               C 2014-05-07       6.92       75591.66      19525.82
# 4               L 2013-06-02     524.96     3296425.02     639077.50
# ..            ...        ...        ...            ...           ...
# 95              M 2011-03-09      35.84       97040.64      65214.72
# 96              L 2011-12-28       6.92       58471.11      15103.47
# 97              C 2016-06-29      90.93      228779.10      93748.05
# 98              M 2015-08-08      56.67      471336.91     144521.02
# 99              L 2012-02-15     502.54     3586605.09     889472.91
#
# [100 rows x 5 columns]

# %%
data={"StudentName": ["Reena", "Anil", "Mansi", "Jaman","Reena"],
        "Age": [24, 28, 26, 24,24],
        "Sex": ["Female", "Male", "Female", "Male","Female"]}

st=pd.DataFrame(data)
st
# Out:
#   StudentName  Age     Sex
# 0       Reena   24  Female
# 1        Anil   28    Male
# 2       Mansi   26  Female
# 3       Jaman   24    Male
# 4       Reena   24  Female

# %%
st=st.drop_duplicates()
st
# Out:
#   StudentName  Age     Sex
# 0       Reena   24  Female
# 1        Anil   28    Male
# 2       Mansi   26  Female
# 3       Jaman   24    Male

# %%
new_data=st.sort_values("Age")
print(new_data)
# Out:
#   StudentName  Age     Sex
# 0       Reena   24  Female
# 3       Jaman   24    Male
# 2       Mansi   26  Female
# 1        Anil   28    Male

# %%
new_data=st.sort_values("Age",ascending=False)
new_data
# Out:
#   StudentName  Age     Sex
# 1        Anil   28    Male
# 2       Mansi   26  Female
# 0       Reena   24  Female
# 3       Jaman   24    Male

# %%
new_data=st.sort_values("StudentName",ascending=False)
new_data
# Out:
#   StudentName  Age     Sex
# 0       Reena   24  Female
# 2       Mansi   26  Female
# 3       Jaman   24    Male
# 1        Anil   28    Male

# %%
new_data["Age"][0:3]
# Out:
# 0    24
# 2    26
# 3    24
# Name: Age, dtype: int64

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'], 
                    'B': ['B0', 'B1', 'B2', 'B3'], 
                    'C': ['C0', 'C1', 'C2', 'C3'], 
                    'D': ['D0', 'D1', 'D2', 'D3']}) 
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'], 
                    'B': ['B4', 'B5', 'B6', 'B7'], 
                    'C': ['C4', 'C5', 'C6', 'C7'], 
                    'D': ['D4', 'D5', 'D6', 'D7']})
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'], 
                    'B': ['B8', 'B9', 'B10', 'B11'], 
                    'C': ['C8', 'C9', 'C10', 'C11'], 
                    'D': ['D8', 'D9', 'D10', 'D11']})

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %%
df3
# Out:
#      A    B    C    D
# 0   A8   B8   C8   D8
# 1   A9   B9   C9   D9
# 2  A10  B10  C10  D10
# 3  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3])
# Out:
#      A    B    C    D
# 0   A0   B0   C0   D0
# 1   A1   B1   C1   D1
# 2   A2   B2   C2   D2
# 3   A3   B3   C3   D3
# 0   A4   B4   C4   D4
# 1   A5   B5   C5   D5
# 2   A6   B6   C6   D6
# 3   A7   B7   C7   D7
# 0   A8   B8   C8   D8
# 1   A9   B9   C9   D9
# 2  A10  B10  C10  D10
# 3  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3]).reset_index()
# Out:
#     index    A    B    C    D
# 0       0   A0   B0   C0   D0
# 1       1   A1   B1   C1   D1
# 2       2   A2   B2   C2   D2
# 3       3   A3   B3   C3   D3
# 4       0   A4   B4   C4   D4
# 5       1   A5   B5   C5   D5
# 6       2   A6   B6   C6   D6
# 7       3   A7   B7   C7   D7
# 8       0   A8   B8   C8   D8
# 9       1   A9   B9   C9   D9
# 10      2  A10  B10  C10  D10
# 11      3  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3],axis=1).reset_index()
# Out:
#    index   A   B   C   D   A   B   C   D    A    B    C    D
# 0      0  A0  B0  C0  D0  A4  B4  C4  D4   A8   B8   C8   D8
# 1      1  A1  B1  C1  D1  A5  B5  C5  D5   A9   B9   C9   D9
# 2      2  A2  B2  C2  D2  A6  B6  C6  D6  A10  B10  C10  D10
# 3      3  A3  B3  C3  D3  A7  B7  C7  D7  A11  B11  C11  D11

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item_Type', 'Sales_Channel', 'Order_Priority',
#        'Ship_Date', 'Unit_Cost', 'Total_Revenue', 'Total_Profit'],
#       dtype='object')

# %%
df.groupby(["Sales_Channel"]).mean()
# Out:
#                Unit_Cost  Total_Revenue  Total_Profit
# Sales_Channel
# Offline          216.823   1.581896e+06   498414.5334
# Online           165.273   1.165079e+06   384949.4346

# %%
df.groupby(["Region"])["Region"].count()
# Out:
# Region
# Asia                                 11
# Australia and Oceania                11
# Central America and the Caribbean     7
# Europe                               22
# Middle East and North Africa         10
# North America                         3
# Sub_Saharan Africa                   36
# Name: Region, dtype: int64

# %%
df.groupby(["Sales_Channel"])["Total_Revenue"].mean()
# Out:
# Sales_Channel
# Offline    1.581896e+06
# Online     1.165079e+06
# Name: Total_Revenue, dtype: float64

# %%
df.groupby(["Item_Type","Region"]).count()["Sales_Channel"]
# Out:
# Item_Type        Region
# Baby Food        Australia and Oceania                2
#                  Europe                               4
#                  Sub_Saharan Africa                   1
# Beverages        Australia and Oceania                2
#                  Central America and the Caribbean    1
#                  Europe                               2
#                  Sub_Saharan Africa                   3
# Cereal           Australia and Oceania                1
#                  Central America and the Caribbean    1
#                  Middle East and North Africa         1
#                  Sub_Saharan Africa                   4
# Clothes          Asia                                 2
#                  Australia and Oceania                1
#                  Central America and the Caribbean    1
#                  Europe                               3
#                  Middle East and North Africa         2
# ...

# %%
df.groupby(["Region","Item_Type"]).count()['Sales_Channel']
# Out:
# Region                             Item_Type
# Asia                               Clothes            2
#                                    Cosmetics          1
#                                    Fruits             1
#                                    Household          2
#                                    Office Supplies    2
#                                    Personal Care      1
#                                    Vegetables         2
# Australia and Oceania              Baby Food          2
#                                    Beverages          2
#                                    Cereal             1
#                                    Clothes            1
#                                    Cosmetics          1
#                                    Fruits             2
#                                    Meat               1
#                                    Office Supplies    1
# Central America and the Caribbean  Beverages          1
# ...

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item_Type', 'Sales_Channel', 'Order_Priority',
#        'Ship_Date', 'Unit_Cost', 'Total_Revenue', 'Total_Profit'],
#       dtype='object')

# %%
pd.pivot_table(df,index=["Sales_Channel","Order_Priority"],aggfunc="sum")
# Out:
#                               Total_Profit  Total_Revenue  Unit_Cost
# Sales_Channel Order_Priority
# Offline       C                 3625315.71    10316782.15    1553.33
#               H                 9875825.95    31772954.03    3888.88
#               L                 6341300.86    22142428.99    3536.18
#               M                 5078284.15    14862644.03    1862.76
# Online        C                 3123012.75     8538280.90    1207.00
#               H                 7015773.63    16976592.02    1819.18
#               L                 4517427.00    14485698.47    2152.87
#               M                 4591258.35    18253387.72    3084.60

# %%
pd.pivot_table(df,index=["Region","Sales_Channel"],aggfunc="mean")
# Out:
#                                                  Total_Profit  Total_Revenue  \
# Region                            Sales_Channel
# Asia                              Offline        5.973811e+05   2.024350e+06
#                                   Online         5.059119e+05   1.840199e+06
# Australia and Oceania             Offline        4.715710e+05   1.050467e+06
#                                   Online         4.051252e+05   1.413200e+06
# Central America and the Caribbean Offline        4.951630e+05   1.650822e+06
#                                   Online         1.855464e+05   4.581367e+05
# Europe                            Offline        6.193933e+05   2.013610e+06
#                                   Online         4.237230e+05   1.172804e+06
# Middle East and North Africa      Offline        1.084541e+06   2.496569e+06
#                                   Online         4.490138e+05   1.132446e+06
# ...

# %%
pd.pivot_table(df,index=["Region","Sales_Channel"],values="Unit_Cost",aggfunc="std")
# Out:
#                                                   Unit_Cost
# Region                            Sales_Channel
# Asia                              Offline        222.938677
#                                   Online         258.823047
# Australia and Oceania             Offline         62.751021
#                                   Online         200.408732
# Central America and the Caribbean Offline        205.496480
#                                   Online          13.908790
# Europe                            Offline        213.242415
#                                   Online         163.533986
# Middle East and North Africa      Offline        160.859722
#                                   Online         185.830989
# North America                     Offline        257.423165
# Sub_Saharan Africa                Offline        214.038829
#                                   Online         143.917960

# %%
pd.pivot_table(df,index=["Region","Sales_Channel"])
# Out:
#                                                  Total_Profit  Total_Revenue  \
# Region                            Sales_Channel
# Asia                              Offline        5.973811e+05   2.024350e+06
#                                   Online         5.059119e+05   1.840199e+06
# Australia and Oceania             Offline        4.715710e+05   1.050467e+06
#                                   Online         4.051252e+05   1.413200e+06
# Central America and the Caribbean Offline        4.951630e+05   1.650822e+06
#                                   Online         1.855464e+05   4.581367e+05
# Europe                            Offline        6.193933e+05   2.013610e+06
#                                   Online         4.237230e+05   1.172804e+06
# Middle East and North Africa      Offline        1.084541e+06   2.496569e+06
#                                   Online         4.490138e+05   1.132446e+06
# ...

# %%
pd.crosstab(df.Sales_Channel,df.Region)
# Out:
# Region         Asia  Australia and Oceania  Central America and the Caribbean  \
# Sales_Channel
# Offline           6                      4                                  5
# Online            5                      7                                  2
#
# Region         Europe  Middle East and North Africa  North America  \
# Sales_Channel
# Offline             9                             2              3
# Online             13                             8              0
#
# Region         Sub_Saharan Africa
# Sales_Channel
# Offline                        21
# Online                         15

# %%
df.to_csv("Result.csv")

# %%
pwd
# Out:
# 'C:\\Users\\viral\\Desktop\\Python\\Practice Class\\Pandas\\Session 1'

# %%
user_usage=pd.read_csv("user_usage.csv")
user_device=pd.read_csv("user_device.csv")

# %%
user_device
# Out:
#      use_id  user_id platform  platform_version                  device  \
# 0     22782    26980      ios              10.2               iPhone7,2
# 1     22783    29628  android               6.0                 Nexus 5
# 2     22784    28473  android               5.1                SM-G903F
# 3     22785    15200      ios              10.2               iPhone7,2
# 4     22786    28239  android               6.0               ONE E1003
# ..      ...      ...      ...               ...                     ...
# 267   23049    29725  android               6.0                SM-G900F
# 268   23050    29726      ios              10.2               iPhone7,2
# 269   23051    29726      ios              10.2               iPhone7,2
# 270   23052    29727      ios              10.1               iPhone8,4
# 271   23053    20257  android               5.1  Vodafone Smart ultra 6
#
#      use_type_id
# 0              2
# 1              3
# 2              1
# 3              3
# ...

# %%
user_usage
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# ..                       ...                     ...         ...     ...
# 235                   260.66                   68.44      896.96   25008
# 236                    97.12                   36.50     2815.00   25040
# 237                   355.93                   12.37     6828.09   25046
# 238                   632.06                  120.46     1453.16   25058
# 239                   488.70                  906.92     3089.85   25220
#
# [240 rows x 4 columns]

# %%
result=pd.merge(user_usage,user_device,left_on="use_id",right_on="use_id",how="inner")

# %%
result
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# ..                       ...                     ...         ...     ...
# 154                   198.59                   90.49     5191.12   23043
# 155                   198.59                   90.49     3114.67   23044
# 156                   106.65                   82.13     5191.12   23046
# 157                   344.53                   20.53      519.12   23049
# 158                    42.75                   46.83     5191.12   23053
#
#      user_id platform  platform_version                  device  use_type_id
# ...

# %%
result=pd.merge(user_usage,user_device[["use_id","platform","device"]],left_on="use_id",right_on="use_id",how="inner")

# %%
result
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# ..                       ...                     ...         ...     ...
# 154                   198.59                   90.49     5191.12   23043
# 155                   198.59                   90.49     3114.67   23044
# 156                   106.65                   82.13     5191.12   23046
# 157                   344.53                   20.53      519.12   23049
# 158                    42.75                   46.83     5191.12   23053
#
#     platform                  device
# 0    android                GT-I9505
# ...

# %%
result=pd.merge(user_usage,user_device,left_on="use_id",right_on="use_id",how="left")
result
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# ..                       ...                     ...         ...     ...
# 235                   260.66                   68.44      896.96   25008
# 236                    97.12                   36.50     2815.00   25040
# 237                   355.93                   12.37     6828.09   25046
# 238                   632.06                  120.46     1453.16   25058
# 239                   488.70                  906.92     3089.85   25220
#
#      user_id platform  platform_version    device  use_type_id
# ...

# %%
result=pd.merge(user_usage,user_device,left_on="use_id",right_on="use_id",how="right")
result
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                        NaN                     NaN         NaN   22782
# 1                        NaN                     NaN         NaN   22783
# 2                        NaN                     NaN         NaN   22784
# 3                        NaN                     NaN         NaN   22785
# 4                        NaN                     NaN         NaN   22786
# ..                       ...                     ...         ...     ...
# 267                   344.53                   20.53      519.12   23049
# 268                      NaN                     NaN         NaN   23050
# 269                      NaN                     NaN         NaN   23051
# 270                      NaN                     NaN         NaN   23052
# 271                    42.75                   46.83     5191.12   23053
#
#      user_id platform  platform_version                  device  use_type_id
# ...

# %%
result=pd.merge(user_usage,user_device,left_on="use_id",right_on="use_id",how="outer")
result
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# ..                       ...                     ...         ...     ...
# 348                      NaN                     NaN         NaN   23047
# 349                      NaN                     NaN         NaN   23048
# 350                      NaN                     NaN         NaN   23050
# 351                      NaN                     NaN         NaN   23051
# 352                      NaN                     NaN         NaN   23052
#
#      user_id platform  platform_version         device  use_type_id
# ...
