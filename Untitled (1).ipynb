# %%
import pandas as pd
df=pd.read_csv("Power_BI_Query_Editing_Assignment_1topic_added1616073850s_p702870162.csv", encoding='windows-1252')

# %%
df
# Out:
#      Order Priority  Unit Price           Product Sub-Category  \
# 0     not specified        2.88                         Labels
# 1              high        2.84            Pens & Art Supplies
# 2     not specified        6.68                          Paper
# 3     not specified        5.68  Scissors, Rulers and Trimmers
# 4     not specified      205.99   Telephones and Communication
# ...             ...         ...                            ...
# 9421       critical       35.89                      Envelopes
# 9422       critical        3.34            Pens & Art Supplies
# 9423  not specified      550.98                         Tables
# 9424           high      105.98             Office Furnishings
# 9425  not specified        7.78                      Envelopes
#
#                 Customer Order Date       Ship Mode  Discount  Row ID  \
# 0       Janice Fletcher2  5/28/2012     Regular Air      0.01   18606
# ...

# %%
df["Order Date"]=pd.to_datetime(df["Order Date"],format="%m/%d/%Y")

# %%
df["Ship Date"]=pd.to_datetime(df["Ship Date"],format="%m/%d/%Y")

# %%
df.to_csv("Power_BI_Query_Editing_Assignment_1topic_added1616073850s_p702870162 1.csv",index=False)
